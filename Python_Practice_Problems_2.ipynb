# %% [markdown]
# <a href="https://colab.research.google.com/github/ajai1996/python_practice/blob/main/Python_Practice_Problems_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Write a Python program to accept a string value from the user and display the count of each character in that string. Sample input: Enter a string value: assembly Sample output: a=1, s=2, e=1, m=1, b=1, l=1, y=1

# %%
def count_characters(text):
    char_counts = {}
    for char in text:
        char_counts[char] = char_counts.get(char, 0) + 1
    return char_counts

input_string = input("Enter a string value: ")

frequencies = count_characters(input_string)

output = []
for char, count in frequencies.items():
    output.append(f"{char}={count}")

print("output:", ", ".join(output))
# Out:
# Enter a string value: hello
# output: h=1, e=1, l=2, o=1

# %% [markdown]
# #2.Write a Python function to find the maximum of three numbers Sample input: 34,12,7 Sample output: 34

# %%
def find_maximum(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c

print("Enter three numbers to find the maximum.")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

maximum = find_maximum(num1, num2, num3)

print("output:", int(maximum) if maximum == int(maximum) else maximum)
# Out:
# Enter three numbers to find the maximum.
# Enter first number: 45
# Enter second number: 34
# Enter third number: 87
# output: 87

# %% [markdown]
# #3. Write a Python function called exponent(base,exp) that returns an integer value of base raises to the power of exp. Sample input: Enter the base: 2 Enter the exponent: 3 Sample output: 8

# %%
def exponent(base, exp):
    result = 1

    if exp == 0:
        return 1

    if exp > 0:
        for _ in range(exp):
            result *= base
        return result

    else:
        positive_exp = -exp
        for _ in range(positive_exp):
            result *= base

        return 1 / result

print("Exponent Calculator (base^exp)")
base_input = float(input("Enter the base: "))
exp_input = int(input("Enter the exponent: "))

result = exponent(base_input, exp_input)

if result == int(result):
    print("output:", int(result))
else:
    print("output:", result)
# Out:
# Exponent Calculator (base^exp)
# Enter the base: 10
# Enter the exponent: 2
# output: 100

# %% [markdown]
# #4.Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number. Sample input: 4 Sample output: 36.

# %%
def sum_of_cubes_smaller_than(n):
    total_sum = 0

    for i in range(1, n):
        total_sum += i ** 3

    return total_sum

print("Sum of Cubes Calculator")
input_number = int(input("Enter a positive integer: "))

if input_number <= 1:
    print("The input must be a positive integer greater than 1.")
else:
    result = sum_of_cubes_smaller_than(input_number)
    print("output:", result)
# Out:
# Sum of Cubes Calculator
# Enter a positive integer: 3
# output: 9

# %% [markdown]
# #5. Write a Python program which iterates from 1 to 10. For multiples of 2, print “Fizz” instead of the number and for the multiples of 5, print “Buzz”. For numbers which are multiples of both 2 and 5, print “FizzBuzz”. Sample input: numbers from 1 to 10 Sample output: 1 Fizz 3 Fizz Buzz Fizz 7 Fizz 9 FizzBuzz

# %% [markdown]
# #6. Write a Python program to find the most frequent item in a list of numbers. Sample input: 2, 3, 4, 2, 5, 2 Sample output: 2

# %%
def find_most_frequent(data_list):
    frequency = {}

    for item in data_list:
        frequency[item] = frequency.get(item, 0) + 1

    most_frequent_item = None
    max_count = 0

    for item, count in frequency.items():
        if count > max_count:
            max_count = count
            most_frequent_item = item

    return most_frequent_item

print("Most Frequent Item Finder")

input_str = input("Enter a list of numbers (comma separated): ")

number_list = [int(n.strip()) for n in input_str.split(',')]

result = find_most_frequent(number_list)

print("output:", result)
# Out:
# Most Frequent Item Finder
# Enter a list of numbers (comma separated): 2,4,3,3,5,64,7
# output: 3

# %% [markdown]
# #7. Write a Python program to find the sum of squares of the numbers in a list. Sample input: 2,1,3,1 Sample output: 15

# %%
def calculate_sum_of_squares(number_list):
    total_sum = 0
    for number in number_list:
        total_sum += number * number
    return total_sum

print("Sum of Squares Calculator")

input_str = input("Enter a list of numbers : ")

number_list = [int(n.strip()) for n in input_str.split(',')]

result = calculate_sum_of_squares(number_list)

print("output:", result)
# Out:
# Sum of Squares Calculator
# Enter a list of numbers (comma separated, e.g., 2,1,3,1): 1,2,3
# output: 14

# %% [markdown]
# #8.Write a Python program using for loop that will iterate from 1 to 15. For each iteration, check if the current number is odd or even, and display the message to the screen as odd or even. Sample input: 1….15 Sample output: 1-odd 2-even …. 15-odd

# %%
def check_odd_even(start, end):
    for i in range(start, end + 1):
        if i % 2 == 0:
            print(f"{i}-even")
        else:
            print(f"{i}-odd")

print("Checking numbers from 1 to 15:")
check_odd_even(1, 15)
# Out:
# Checking numbers from 1 to 15:
# 1-odd
# 2-even
# 3-odd
# 4-even
# 5-odd
# 6-even
# 7-odd
# 8-even
# 9-odd
# 10-even
# 11-odd
# 12-even
# 13-odd
# 14-even
# 15-odd

# %% [markdown]
# #9. Write a Python program to convert temperatures to and from Celsius Fahrenheit. [Formula: c/5=f-32/9 where c=temperature in Celsius and f= temperature in Fahrenheit.] Sample input: Temperature in Fahrenheit =41 Sample output: Temperature in Celsius =5

# %%
def fahrenheit_to_celsius(f):
    return (f - 32) * 5 / 9

print("Fahrenheit to Celsius Converter")

fahrenheit_input = float(input("Enter temperature in Fahrenheit: "))
celsius_output = fahrenheit_to_celsius(fahrenheit_input)

print(f"Sample output: Temperature in Celsius = {int(round(celsius_output))}")
# Out:
# Fahrenheit to Celsius Converter
# Enter temperature in Fahrenheit: 100
# Sample output: Temperature in Celsius = 38

# %% [markdown]
# #10. Write a Python function to calculate the factorial of a number (a nonnegative integer). The function accepts the number as an argument. Sample input: 3 Sample output: 6

# %%
def calculate_factorial(n):
    if n == 0 or n == 1:
        return 1

    result = 1
    for i in range(1, n + 1):
        result *= i

    return result

print("Factorial Calculator")
number = int(input("Enter a non-negative integer: "))

if number < 0:
    print("Factorial is not defined for negative numbers.")
else:
    output = calculate_factorial(number)
    print("Sample output:", output)
# Out:
# Factorial Calculator
# Enter a non-negative integer: 5
# Sample output: 120
